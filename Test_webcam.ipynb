# %%
pip install opencv-python-headless ipython
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import cv2
from IPython.display import display, Javascript, HTML
import time

# Create a VideoCapture object to access the webcam
cap = cv2.VideoCapture(0)

# Check if the webcam is opened successfully
if not cap.isOpened():
    print("Error: Could not open webcam")
else:
    # Read a frame from the webcam
    ret, frame = cap.read()

    # Display the captured image using OpenCV
    cv2.imshow("Captured Image", frame)
    
    # Save the captured image
    image_filename = "captured_image.jpg"
    cv2.imwrite(image_filename, frame)
    print(f"Image saved as {image_filename}")

    # Release the webcam and close OpenCV windows
    cap.release()
    cv2.destroyAllWindows()

    # Display a link to download the captured image
    display(HTML(f'<a href="{image_filename}" download>Click here to download the captured image</a>'))
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# Cell In[1], line 16
#      13 ret, frame = cap.read()
#      15 # Display the captured image using OpenCV
# ---> 16 cv2.imshow("Captured Image", frame)
#      18 # Save the captured image
#      19 image_filename = "captured_image.jpg"
#
# error: OpenCV(4.8.0) D:\a\opencv-python\opencv-python\opencv\modules\highgui\src\window.cpp:1272: error: (-2:Unspecified error) The function is not implemented. Rebuild the library with Windows, GTK+ 2.x or Cocoa support. If you are on Ubuntu or Debian, install libgtk2.0-dev and pkg-config, then re-run cmake or configure script in function 'cvShowImage'

# %%
import cv2
from IPython.display import display, Image
import time
import io
import PIL.Image

# Create a VideoCapture object to access the webcam
cap = cv2.VideoCapture(0)

# Check if the webcam is opened successfully
if not cap.isOpened():
    print("Error: Could not open webcam")
else:
    # Read a frame from the webcam
    ret, frame = cap.read()

    # Convert the OpenCV image to a format that can be displayed in IPython
    frame_rgb = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
    pil_image = PIL.Image.fromarray(frame_rgb)

    # Display the captured image in the notebook
    display(pil_image)
    
    # Save the captured image
    image_filename = "captured_image.jpg"
    cv2.imwrite(image_filename, frame)
    print(f"Image saved as {image_filename}")

    # Release the webcam
    cap.release()

    # Display a link to download the captured image
    display(Image(filename=image_filename))
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# Cell In[2], line 18
#      15 ret, frame = cap.read()
#      17 # Convert the OpenCV image to a format that can be displayed in IPython
# ---> 18 frame_rgb = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
#      19 pil_image = PIL.Image.fromarray(frame_rgb)
#      21 # Display the captured image in the notebook
#
# error: OpenCV(4.8.0) D:\a\opencv-python\opencv-python\opencv\modules\imgproc\src\color.cpp:182: error: (-215:Assertion failed) !_src.empty() in function 'cv::cvtColor'

# %%
import cv2
from IPython.display import display, Image
import time
import io
import PIL.Image

# Create a VideoCapture object to access the webcam
cap = cv2.VideoCapture(0)

# Check if the webcam is opened successfully
if not cap.isOpened():
    print("Error: Could not open webcam")
else:
    # Read a frame from the webcam
    ret, frame = cap.read()

    # Convert the OpenCV image to a format that can be displayed in IPython
    frame_rgb = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
    pil_image = PIL.Image.fromarray(frame_rgb)

    # Display the captured image in the notebook
    display(pil_image)
    
    # Save the captured image
    image_filename = "captured_image.jpg"
    cv2.imwrite(image_filename, frame)
    print(f"Image saved as {image_filename}")

    # Release the webcam
    cap.release()

    # Display a link to download the captured image
    display(Image(filename=image_filename))
# Out:
# <PIL.Image.Image image mode=RGB size=640x480>
# Image saved as captured_image.jpg

# %%
pip install ipywidgets
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import cv2
from IPython.display import display, Image
import time
import io
import PIL.Image
import ipywidgets as widgets
from IPython.display import display

# Create a VideoCapture object to access the webcam
cap = cv2.VideoCapture(0)

# Create a button widget
capture_button = widgets.Button(description='Capture Image')
display(capture_button)

def capture_image(_):
    # Read a frame from the webcam
    ret, frame = cap.read()

    if ret:
        # Convert the OpenCV image to a format that can be displayed in IPython
        frame_rgb = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
        pil_image = PIL.Image.fromarray(frame_rgb)

        # Display the captured image in the notebook
        display(pil_image)

        # Save the captured image
        image_filename = "captured_image.jpg"
        cv2.imwrite(image_filename, frame)
        print(f"Image saved as {image_filename}")

        # Display a link to download the captured image
        display(Image(filename=image_filename))
    else:
        print("Error: Could not capture image")

# Link the button click event to the capture_image function
capture_button.on_click(capture_image)
# Out:
# Button(description='Capture Image', style=ButtonStyle())
# <PIL.Image.Image image mode=RGB size=640x480>
# Image saved as captured_image.jpg

# %%
import cv2
from IPython.display import display, Image
import time
import io
import PIL.Image
import ipywidgets as widgets
from IPython.display import display

# Create a button widget
capture_button = widgets.Button(description='Capture Image')
display(capture_button)

def capture_image(_):
    # Create a VideoCapture object to access the webcam
    cap = cv2.VideoCapture(0)

    # Read a frame from the webcam
    ret, frame = cap.read()

    if ret:
        # Convert the OpenCV image to a format that can be displayed in IPython
        frame_rgb = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
        pil_image = PIL.Image.fromarray(frame_rgb)

        # Display the captured image in the notebook
        display(pil_image)

        # Save the captured image
        image_filename = "captured_image.jpg"
        cv2.imwrite(image_filename, frame)
        print(f"Image saved as {image_filename}")

        # Display a link to download the captured image
        display(Image(filename=image_filename))
    else:
        print("Error: Could not capture image")
    
    # Release the webcam
    cap.release()

# Link the button click event to the capture_image function
capture_button.on_click(capture_image)
# Out:
# Button(description='Capture Image', style=ButtonStyle())
# <PIL.Image.Image image mode=RGB size=640x480>
# Image saved as captured_image.jpg

# %%
import cv2
import ipywidgets as widgets
from IPython.display import display
import numpy as np

# Create a button widget
capture_button = widgets.Button(description='Capture Image')
display(capture_button)

# Create an output widget to display the live webcam feed
output = widgets.Output()
display(output)

# Function to capture and display the webcam feed
def show_webcam():
    cap = cv2.VideoCapture(0)
    try:
        while True:
            ret, frame = cap.read()
            if not ret:
                break

            # Convert the OpenCV image to a format that can be displayed in IPython
            frame_rgb = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
            pil_image = PIL.Image.fromarray(frame_rgb)

            # Display the captured image in the notebook
            with output:
                output.clear_output(wait=True)
                display(pil_image)
                
            # Delay to control the frame rate of the webcam feed
            time.sleep(0.1)
    finally:
        cap.release()

# Function to capture an image and display it
def capture_image(_):
    cap = cv2.VideoCapture(0)
    try:
        ret, frame = cap.read()
        if ret:
            # Convert the OpenCV image to a format that can be displayed in IPython
            frame_rgb = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
            pil_image = PIL.Image.fromarray(frame_rgb)

            # Display the captured image in the notebook
            with output:
                output.clear_output(wait=True)
                display(pil_image)

            # Save the captured image
            image_filename = "captured_image.jpg"
            cv2.imwrite(image_filename, frame)
            print(f"Image saved as {image_filename}")

            # Display a link to download the captured image
            display(widgets.Image(value=open(image_filename, 'rb').read()))
    finally:
        cap.release()

# Link the button click event to the capture_image function
capture_button.on_click(capture_image)

# Start showing the live webcam feed
show_webcam()
# Out:
# Button(description='Capture Image', style=ButtonStyle())
# Output()

# %%
import cv2
import ipywidgets as widgets
from IPython.display import display, clear_output
import PIL.Image

# Create a button widget
capture_button = widgets.Button(description='Capture Image')
display(capture_button)

# Create an output widget to display the webcam feed
webcam_output = widgets.Output()
display(webcam_output)

# Create an output widget to display the captured image
captured_image_output = widgets.Output()
display(captured_image_output)

# Create a VideoCapture object to access the webcam
cap = cv2.VideoCapture(0)

# Function to capture and display the webcam feed
def show_webcam(_):
    try:
        while True:
            ret, frame = cap.read()
            if not ret:
                break

            # Convert the OpenCV image to a format that can be displayed in IPython
            frame_rgb = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
            pil_image = PIL.Image.fromarray(frame_rgb)

            # Display the webcam feed
            with webcam_output:
                clear_output(wait=True)
                display(pil_image)
                
    except KeyboardInterrupt:
        pass
    finally:
        cap.release()
        with webcam_output:
            clear_output(wait=True)

# Function to capture an image and display it
def capture_image(_):
    ret, frame = cap.read()
    if ret:
        # Convert the OpenCV image to a format that can be displayed in IPython
        frame_rgb = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
        pil_image = PIL.Image.fromarray(frame_rgb)

        # Display the captured image
        with captured_image_output:
            clear_output(wait=True)
            display(pil_image)

        # Save the captured image
        image_filename = "captured_image.jpg"
        cv2.imwrite(image_filename, frame)
        print(f"Image saved as {image_filename}")

        # Display a link to download the captured image
        display(widgets.Image(value=open(image_filename, 'rb').read()))

# Link the button click events to the appropriate functions
capture_button.on_click(capture_image)
show_webcam_button = widgets.Button(description='Show Webcam')
display(show_webcam_button)
show_webcam_button.on_click(show_webcam)
# Out:
# Button(description='Capture Image', style=ButtonStyle())
# Output()
# Output()
# Button(description='Show Webcam', style=ButtonStyle())

# %%
import cv2
import threading
import ipywidgets as widgets
from IPython.display import display, clear_output
import PIL.Image

# Create a button widget
capture_button = widgets.Button(description='Capture Image')
display(capture_button)

# Create an output widget to display the webcam feed
webcam_output = widgets.Output()
display(webcam_output)

# Create an output widget to display the captured image
captured_image_output = widgets.Output()
display(captured_image_output)

# Create a VideoCapture object to access the webcam
cap = cv2.VideoCapture(0)

# Variable to control the webcam display thread
webcam_thread_running = False

# Function to capture and display the webcam feed
def show_webcam():
    global webcam_thread_running
    try:
        while webcam_thread_running:
            ret, frame = cap.read()
            if not ret:
                break

            # Convert the OpenCV image to a format that can be displayed in IPython
            frame_rgb = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
            pil_image = PIL.Image.fromarray(frame_rgb)

            # Display the webcam feed
            with webcam_output:
                clear_output(wait=True)
                display(pil_image)
                
    except KeyboardInterrupt:
        pass
    finally:
        cap.release()
        with webcam_output:
            clear_output(wait=True)

# Function to capture an image and display it
def capture_image(_):
    global webcam_thread_running
    webcam_thread_running = False  # Stop the webcam thread
    
    ret, frame = cap.read()
    if ret:
        # Convert the OpenCV image to a format that can be displayed in IPython
        frame_rgb = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
        pil_image = PIL.Image.fromarray(frame_rgb)

        # Display the captured image
        with captured_image_output:
            clear_output(wait=True)
            display(pil_image)

        # Save the captured image
        image_filename = "captured_image.jpg"
        cv2.imwrite(image_filename, frame)
        print(f"Image saved as {image_filename}")

        # Display a link to download the captured image
        display(widgets.Image(value=open(image_filename, 'rb').read()))

# Link the button click events to the appropriate functions
capture_button.on_click(capture_image)

# Start showing the webcam feed in a separate thread
webcam_thread_running = True
webcam_thread = threading.Thread(target=show_webcam)
webcam_thread.start()
# Out:
# Button(description='Capture Image', style=ButtonStyle())
# Output()
# Output()
# Image saved as captured_image.jpg
# Image(value=b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x01\x01\x00\x00\x01\x00\x01\x00\x00\xff\xdb\x00C\x00\x02\x01\x0…
